# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /home/vscode/.local/lib/python3.11/site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in /home/vscode/.local/lib/python3.11/site-packages (from scikit-learn) (2.1.0)
# Requirement already satisfied: scipy>=1.6.0 in /home/vscode/.local/lib/python3.11/site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/vscode/.local/lib/python3.11/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/vscode/.local/lib/python3.11/site-packages (from scikit-learn) (3.5.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_csv('salaryData.csv')

df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df.shape
# Out:
# (375, 6)

# %%
df.describe()
# Out:
#               Age  Years of Experience         Salary
# count  373.000000           373.000000     373.000000
# mean    37.431635            10.030831  100577.345845
# std      7.069073             6.557007   48240.013482
# min     23.000000             0.000000     350.000000
# 25%     31.000000             4.000000   55000.000000
# 50%     36.000000             9.000000   95000.000000
# 75%     44.000000            15.000000  140000.000000
# max     53.000000            25.000000  250000.000000

# %%
df.isnull().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        2
# Job Title              2
# Years of Experience    2
# Salary                 2
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
df.describe()
# Out:
#               Age  Years of Experience         Salary
# count  373.000000           373.000000     373.000000
# mean    37.431635            10.030831  100577.345845
# std      7.069073             6.557007   48240.013482
# min     23.000000             0.000000     350.000000
# 25%     31.000000             4.000000   55000.000000
# 50%     36.000000             9.000000   95000.000000
# 75%     44.000000            15.000000  140000.000000
# max     53.000000            25.000000  250000.000000

# %%
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
df.dtypes
# Out:
# Age                    float64
# Gender                  object
# Education Level         object
# Job Title               object
# Years of Experience    float64
# Salary                 float64
# dtype: object

# %%
df['Job Title'].value_counts()
# Out:
# Job Title
# Director of Marketing             12
# Director of Operations            11
# Senior Business Analyst           10
# Senior Marketing Manager           9
# Senior Marketing Analyst           9
#                                   ..
# Junior Social Media Specialist     1
# Junior Operations Coordinator      1
# Senior HR Specialist               1
# Director of HR                     1
# Junior Financial Advisor           1
# Name: count, Length: 174, dtype: int64

# %%
df['Education Level'].value_counts()
# Out:
# Education Level
# Bachelor's    224
# Master's       98
# PhD            51
# Name: count, dtype: int64

# %%
df_edited = df.groupby('Job Title').filter(lambda x : len(x)>4)
df_edited.info()
df_edited['Job Title'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 147 entries, 47 to 374
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  147 non-null    float64
#  1   Gender               147 non-null    object
#  2   Education Level      147 non-null    object
#  3   Job Title            147 non-null    object
#  4   Years of Experience  147 non-null    float64
#  5   Salary               147 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 8.0+ KB
# Job Title
# Director of Marketing                    12
# Director of Operations                   11
# Senior Business Analyst                  10
# Senior Marketing Manager                  9
# Senior Marketing Analyst                  9
# Junior Business Analyst                   8
# Senior Project Manager                    7
# Senior Data Scientist                     7
# Senior Financial Analyst                  7
# Junior Business Development Associate     7
# Junior Financial Analyst                  7
# Senior Software Engineer                  6
# Senior Product Manager                    6
# Junior Marketing Coordinator              6
# Senior Project Coordinator                5
# Junior Operations Analyst                 5
# Junior Marketing Specialist               5
# Senior Product Designer                   5
# Junior Project Manager                    5
# Senior Operations Manager                 5
# Senior Financial Manager                  5
# Name: count, dtype: int64

# %%
df_edited['Job Title'] = df_edited['Job Title'].astype('category')

# %%
df_edited['Job Title Encoded'] = df_edited['Job Title'].cat.codes
df_edited.head()
# Out:
#      Age  Gender Education Level                 Job Title  \
# 47  45.0  Female        Master's     Director of Marketing
# 60  51.0  Female        Master's    Director of Operations
# 63  47.0    Male             PhD     Senior Data Scientist
# 69  49.0  Female        Master's  Senior Financial Analyst
# 77  32.0    Male        Master's  Senior Software Engineer
#
#     Years of Experience    Salary  Job Title Encoded
# 47                 16.0  180000.0                  0
# 60                 23.0  170000.0                  1
# 63                 21.0  180000.0                 10
# 69                 18.0  150000.0                 11
# 77                  6.0  100000.0                 20

# %%
df_edited.dtypes
# Out:
# Age                     float64
# Gender                   object
# Education Level          object
# Job Title              category
# Years of Experience     float64
# Salary                  float64
# Job Title Encoded          int8
# dtype: object

# %%
df_edited['Education Level'] = df_edited['Education Level'].astype('category')

# %%
df_edited.dtypes
# Out:
# Age                     float64
# Gender                   object
# Education Level        category
# Job Title              category
# Years of Experience     float64
# Salary                  float64
# Job Title Encoded          int8
# dtype: object

# %%
df_edited['Education Level Encoded'] = df_edited['Education Level'].cat.codes
df_edited.head()
# Out:
#      Age  Gender Education Level                 Job Title  \
# 47  45.0  Female        Master's     Director of Marketing
# 60  51.0  Female        Master's    Director of Operations
# 63  47.0    Male             PhD     Senior Data Scientist
# 69  49.0  Female        Master's  Senior Financial Analyst
# 77  32.0    Male        Master's  Senior Software Engineer
#
#     Years of Experience    Salary  Job Title Encoded  Education Level Encoded
# 47                 16.0  180000.0                  0                        1
# 60                 23.0  170000.0                  1                        1
# 63                 21.0  180000.0                 10                        2
# 69                 18.0  150000.0                 11                        1
# 77                  6.0  100000.0                 20                        1

# %%
df_edited['Gender'] = df_edited['Gender'].astype('category')

# %%
df_edited['Gender Encoded'] = df_edited['Gender'].cat.codes
df_edited.head()
# Out:
#      Age  Gender Education Level                 Job Title  \
# 47  45.0  Female        Master's     Director of Marketing
# 60  51.0  Female        Master's    Director of Operations
# 63  47.0    Male             PhD     Senior Data Scientist
# 69  49.0  Female        Master's  Senior Financial Analyst
# 77  32.0    Male        Master's  Senior Software Engineer
#
#     Years of Experience    Salary  Job Title Encoded  Education Level Encoded  \
# 47                 16.0  180000.0                  0                        1
# 60                 23.0  170000.0                  1                        1
# 63                 21.0  180000.0                 10                        2
# 69                 18.0  150000.0                 11                        1
# 77                  6.0  100000.0                 20                        1
#
#     Gender Encoded
# 47               0
# 60               0
# 63               1
# 69               0
# 77               1

# %%
df_final = df_edited.drop(['Gender', 'Education Level', 'Job Title'], axis=1)
df_final.head()
# Out:
#      Age  Years of Experience    Salary  Job Title Encoded  \
# 47  45.0                 16.0  180000.0                  0
# 60  51.0                 23.0  170000.0                  1
# 63  47.0                 21.0  180000.0                 10
# 69  49.0                 18.0  150000.0                 11
# 77  32.0                  6.0  100000.0                 20
#
#     Education Level Encoded  Gender Encoded
# 47                        1               0
# 60                        1               0
# 63                        2               1
# 69                        1               0
# 77                        1               1

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 147 entries, 47 to 374
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      147 non-null    float64
#  1   Years of Experience      147 non-null    float64
#  2   Salary                   147 non-null    float64
#  3   Job Title Encoded        147 non-null    int8
#  4   Education Level Encoded  147 non-null    int8
#  5   Gender Encoded           147 non-null    int8
# dtypes: float64(3), int8(3)
# memory usage: 5.0 KB

# %%
import numpy as np
import pickle
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
X = df_final.iloc[:,[0,1,3,4,5]]
y = df_final.iloc[:,2]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
X_train.head()
# Out:
#       Age  Years of Experience  Job Title Encoded  Education Level Encoded  \
# 288  44.0                 13.0                 20                        0
# 346  35.0                  8.0                 13                        0
# 364  35.0                  8.0                 12                        0
# 340  35.0                  8.0                 12                        0
# 280  31.0                  3.0                  7                        0
#
#      Gender Encoded
# 288               1
# 346               0
# 364               0
# 340               0
# 280               1

# %%
y_train.head()
# Out:
# 288    130000.0
# 346     85000.0
# 364     90000.0
# 340     90000.0
# 280     50000.0
# Name: Salary, dtype: float64

# %%
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(X_test)

# %%
err = np.sqrt(mean_squared_error(y_test, y_pred))

# %%
y_pred, y_test
# Out:
# (array([ 98308.47797235,  41281.79316856, 174044.40206946,  45048.39824663,
#          56568.3036832 , 120084.69168845, 150572.41560153, 166332.2572862 ,
#         114256.56293475, 109078.65800073, 174134.17688124, 152173.55015321,
#         168023.16664967, 202893.91164489, 179567.38902808, 130021.26800779,
#          63630.83964322, 172442.65252134,  86783.70914741, 152173.55015321,
#         130021.26800779,  91339.5470899 , 153441.59257248, 174044.40206946,
#         131571.15878237, 115853.4490945 , 149206.51971275, 141483.41815988,
#         126817.35078541,  66170.55787726]),
#  275    120000.0
#  283     35000.0
#  353    180000.0
#  140     40000.0
#  327     55000.0
#  264    110000.0
#  350    160000.0
#  226    160000.0
#  296    130000.0
#  225    105000.0
#  130    160000.0
#  365    170000.0
#  249    170000.0
#  93     170000.0
#  88     135000.0
#  343    150000.0
#  156     50000.0
#  246    180000.0
#  213     85000.0
#  341    170000.0
#  367    150000.0
#  272     90000.0
#  297    160000.0
#  329    180000.0
#  108    100000.0
#  331    130000.0
#  252    150000.0
#  47     180000.0
#  141    110000.0
#  122     50000.0
#  Name: Salary, dtype: float64)

# %%
err
# Out:
# np.float64(17631.48390636018)

# %%
print(pd.DataFrame(zip(X.columns, reg.coef_)))
print(reg.intercept_)
# Out:
#                          0            1
# 0                      Age  1267.427423
# 1      Years of Experience  5177.904934
# 2        Job Title Encoded   424.096937
# 3  Education Level Encoded  6115.455494
# 4           Gender Encoded  2869.176971
# -4512.750305929076

# %%
pickle.dump(reg, open('model.pkl', 'wb'))
